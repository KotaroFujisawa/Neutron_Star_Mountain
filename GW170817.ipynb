# %%
import gwpy
from gwpy.timeseries import TimeSeries
from matplotlib import pyplot as plt
template = TimeSeries.fetch_open_data("L1", 1187008882, 1187008882 + 4096)
#plot = template.plot()
#ax = plot.gca()
#ax.set_ylabel('Strain amplitude')
#ax.set_title('GW170817 template')
plt.plot(template)
plt.show()

# %%
template
# Out:
# <TimeSeries([-1.04289994e-18, -1.03586274e-18, -9.89322445e-19,
#              ..., -1.01767748e-18, -9.82876816e-19,
#              -9.59276974e-19]
#             unit=Unit(dimensionless),
#             t0=<Quantity 1.12625945e+09 s>,
#             dt=<Quantity 0.00024414 s>,
#             name='Strain',
#             channel=None)>
